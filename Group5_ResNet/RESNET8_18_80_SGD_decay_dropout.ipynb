# %% [markdown]
# # CIFAR 10 on RESNET

# %% [markdown]
# ## Libarary Installation

# %%
# !pip install ipython-autotime
# %load_ext autotime
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms


# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# Collecting ipython-autotime
#   Downloading https://files.pythonhosted.org/packages/3f/58/a4a65efcce5c81a67b6893ade862736de355a3a718af5533d30c991831ce/ipython_autotime-0.2.0-py2.py3-none-any.whl
# Requirement already satisfied: ipython in /usr/local/lib/python3.6/dist-packages (from ipython-autotime) (5.5.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (50.3.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (1.0.18)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (4.3.3)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (2.6.1)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (0.8.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->ipython-autotime) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->ipython-autotime) (0.2.5)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython->ipython-autotime) (0.6.0)
# Installing collected packages: ipython-autotime
# Successfully installed ipython-autotime-0.2.0
# time: 3.61 s

# %% [markdown]
# ## Hyper parmeters

# %%
num_epochs = 80
learning_rate = 0.01
# Out:
# time: 696 µs

# %% [markdown]
# # Image preprocessing modules

# %%
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomRotation((0,5)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ColorJitter(brightness=0.5, contrast=0.5, saturation=0, hue=0),
    #transforms.RandomHorizontalFlip(p=0.5),
    #transforms.RandomVerticalFlip(p=0.5),
    #transforms.ColorJitter(brightness=0, contrast=0, saturation=0, hue=0),
    #transforms.RandomRotation(degrees=[-10,10], resample=False, expand=False, center=None, fill=0),
    transforms.ToTensor(),
    #transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    #transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
# Out:
# time: 5.52 ms

# %%
#transform_train = transforms.Compose([
#    transforms.RandomCrop(32, padding=4),
#    transforms.RandomHorizontalFlip(),
#    transforms.ToTensor(),
#    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
#])

#transform_test = transforms.Compose([
#    transforms.ToTensor(),
#    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
#])
# Out:
# time: 1.79 ms

# %% [markdown]
# ## data loading

# %%
# CIFAR-10 dataset
train_dataset = torchvision.datasets.CIFAR10(root='../../data/',
                                             train=True, 
                                             transform=transform,
                                             download=True)

test_dataset = torchvision.datasets.CIFAR10(root='../../data/',
                                            train=False, 
                                            transform=transforms.ToTensor())
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../../data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ../../data/cifar-10-python.tar.gz to ../../data/
# time: 6.51 s

# %%
# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=32, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=32, 
                                          shuffle=False)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# time: 4.8 ms

# %% [markdown]
# ## functions to show an image

# %%
# functions to show an image


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(train_loader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(4)))
# Out:
#  ship  bird  deer  frog
# time: 354 ms

# %% [markdown]
# ## RESNET Architecture

# %%
# 3x3 convolution
def conv3x3(in_channels, out_channels, stride=1):
    return nn.Conv2d(in_channels, out_channels, kernel_size=3, 
                     stride=stride, padding=1, bias=False)
# Out:
# time: 1.51 ms

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        dropout=0.25
        dropout = 0 if dropout is None else dropout
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.dropout = nn.Dropout(dropout)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out = self.dropout(out)
        out += self.shortcut(x)
        out = F.relu(out)
        
        return out
# Out:
# time: 23 ms

# %%
class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        dropout=0.10
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion*planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)
        self.dropout = nn.Dropout(dropout)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out = self.dropout(out)
        out += self.shortcut(x)
        out = F.relu(out)
        return out
# Out:
# time: 30.2 ms

# %%
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 16

        self.conv1 = nn.Conv2d(3, 16, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(16)
        self.layer1 = self._make_layer(block, 16, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 32, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 64, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 128, num_blocks[3], stride=2)
        self.linear = nn.Linear(128*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out
# Out:
# time: 34.7 ms

# %% [markdown]
# ## Different Architecture

# %%
#RESNET-18
model = ResNet(BasicBlock, [2,2,2,2]).to(device)
#RESNET-34
#model = ResNet(BasicBlock, [3,4,6,3]).to(device)
#RESNET-50
#model = ResNet(Bottleneck, [3,4,6,3]).to(device)
#RESNET-101
#model = ResNet(Bottleneck, [3,4,23,3]).to(device)
#RESNET-152
#model = ResNet(Bottleneck, [3,8,36,3]).to(device)
# Out:
# time: 10.4 s

# %% [markdown]
# ## Optimizer and Loss function

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
#optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
#optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate,weight_decay=1e-5)
#optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)
#optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# For updating learning rate
def update_lr(optimizer, lr):    
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
# Out:
# time: 6.69 ms

# %% [markdown]
# ## Training

# %%
# Train the model
total_step = len(train_loader)
curr_lr = learning_rate
for epoch in range(num_epochs):
    correct = 0
    total = 0
    for i,(images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        #if (i+1) % 100 == 0:
          
    print ("Epoch [{}/{}], Train Loss: {:.4f} Train Accuracy: {} %"
                   .format(epoch+1, num_epochs,  loss.item(),round((100 * correct / total),2)))

    # Decay learning rate
    if (epoch+1) % 20 == 0:
        curr_lr /= 3
        update_lr(optimizer, curr_lr)
# Out:
# Epoch [1/80], Train Loss: 1.5722 Train Accuracy: 34.67 %
# Epoch [2/80], Train Loss: 1.3114 Train Accuracy: 52.09 %
# Epoch [3/80], Train Loss: 1.2642 Train Accuracy: 59.49 %
# Epoch [4/80], Train Loss: 0.8430 Train Accuracy: 64.7 %
# Epoch [5/80], Train Loss: 0.9273 Train Accuracy: 68.25 %
# Epoch [6/80], Train Loss: 0.6309 Train Accuracy: 70.76 %
# Epoch [7/80], Train Loss: 1.4710 Train Accuracy: 72.41 %
# Epoch [8/80], Train Loss: 1.1597 Train Accuracy: 73.43 %
# Epoch [9/80], Train Loss: 1.3745 Train Accuracy: 74.47 %
# Epoch [10/80], Train Loss: 0.9555 Train Accuracy: 75.52 %
# Epoch [11/80], Train Loss: 0.7680 Train Accuracy: 76.47 %
# Epoch [12/80], Train Loss: 0.2273 Train Accuracy: 76.82 %
# Epoch [13/80], Train Loss: 0.7263 Train Accuracy: 77.25 %
# Epoch [14/80], Train Loss: 0.5797 Train Accuracy: 77.31 %
# Epoch [15/80], Train Loss: 0.5188 Train Accuracy: 78.0 %
# Epoch [16/80], Train Loss: 0.2898 Train Accuracy: 78.09 %
# Epoch [17/80], Train Loss: 0.5206 Train Accuracy: 78.57 %
# Epoch [18/80], Train Loss: 0.7160 Train Accuracy: 78.69 %
# Epoch [19/80], Train Loss: 0.1895 Train Accuracy: 79.29 %
# Epoch [20/80], Train Loss: 0.3608 Train Accuracy: 79.38 %
# Epoch [21/80], Train Loss: 0.2339 Train Accuracy: 83.0 %
# Epoch [22/80], Train Loss: 0.2478 Train Accuracy: 83.69 %
# Epoch [23/80], Train Loss: 0.7756 Train Accuracy: 84.15 %
# Epoch [24/80], Train Loss: 0.0471 Train Accuracy: 84.27 %
# Epoch [25/80], Train Loss: 0.3969 Train Accuracy: 84.55 %
# Epoch [26/80], Train Loss: 0.5278 Train Accuracy: 84.58 %
# Epoch [27/80], Train Loss: 0.5076 Train Accuracy: 84.73 %
# Epoch [28/80], Train Loss: 0.8920 Train Accuracy: 84.48 %
# Epoch [29/80], Train Loss: 0.5767 Train Accuracy: 84.7 %
# Epoch [30/80], Train Loss: 0.4825 Train Accuracy: 84.89 %
# Epoch [31/80], Train Loss: 0.4321 Train Accuracy: 84.86 %
# Epoch [32/80], Train Loss: 0.5069 Train Accuracy: 84.83 %
# Epoch [33/80], Train Loss: 0.5832 Train Accuracy: 85.04 %
# Epoch [34/80], Train Loss: 0.3512 Train Accuracy: 84.91 %
# Epoch [35/80], Train Loss: 0.4544 Train Accuracy: 85.0 %
# Epoch [36/80], Train Loss: 0.3391 Train Accuracy: 85.27 %
# Epoch [37/80], Train Loss: 0.1778 Train Accuracy: 84.96 %
# Epoch [38/80], Train Loss: 0.6780 Train Accuracy: 85.25 %
# Epoch [39/80], Train Loss: 0.4000 Train Accuracy: 85.22 %
# Epoch [40/80], Train Loss: 0.4939 Train Accuracy: 85.35 %
# Epoch [41/80], Train Loss: 0.1474 Train Accuracy: 87.49 %
# Epoch [42/80], Train Loss: 0.0862 Train Accuracy: 87.73 %
# Epoch [43/80], Train Loss: 0.3029 Train Accuracy: 88.2 %
# Epoch [44/80], Train Loss: 0.1128 Train Accuracy: 88.52 %
# Epoch [45/80], Train Loss: 0.9006 Train Accuracy: 88.55 %
# Epoch [46/80], Train Loss: 0.5147 Train Accuracy: 88.4 %
# Epoch [47/80], Train Loss: 0.2856 Train Accuracy: 88.91 %
# Epoch [48/80], Train Loss: 0.1110 Train Accuracy: 88.75 %
# Epoch [49/80], Train Loss: 0.7059 Train Accuracy: 88.75 %
# Epoch [50/80], Train Loss: 0.4308 Train Accuracy: 88.83 %
# Epoch [51/80], Train Loss: 0.6889 Train Accuracy: 89.15 %
# Epoch [52/80], Train Loss: 0.2325 Train Accuracy: 89.01 %
# Epoch [53/80], Train Loss: 0.6415 Train Accuracy: 89.04 %
# Epoch [54/80], Train Loss: 0.3123 Train Accuracy: 89.13 %
# Epoch [55/80], Train Loss: 0.2414 Train Accuracy: 89.2 %
# Epoch [56/80], Train Loss: 0.1285 Train Accuracy: 88.99 %
# Epoch [57/80], Train Loss: 0.2542 Train Accuracy: 89.2 %
# Epoch [58/80], Train Loss: 0.4993 Train Accuracy: 89.0 %
# Epoch [59/80], Train Loss: 0.4624 Train Accuracy: 89.14 %
# Epoch [60/80], Train Loss: 0.2973 Train Accuracy: 89.3 %
# Epoch [61/80], Train Loss: 0.6007 Train Accuracy: 90.35 %
# Epoch [62/80], Train Loss: 0.7355 Train Accuracy: 90.65 %
# Epoch [63/80], Train Loss: 0.2857 Train Accuracy: 90.75 %
# Epoch [64/80], Train Loss: 0.3148 Train Accuracy: 90.81 %
# Epoch [65/80], Train Loss: 0.1039 Train Accuracy: 90.86 %
# Epoch [66/80], Train Loss: 0.1534 Train Accuracy: 90.77 %
# Epoch [67/80], Train Loss: 0.5909 Train Accuracy: 90.83 %
# Epoch [68/80], Train Loss: 0.2494 Train Accuracy: 90.93 %
# Epoch [69/80], Train Loss: 0.3101 Train Accuracy: 91.13 %
# Epoch [70/80], Train Loss: 0.3131 Train Accuracy: 91.07 %
# Epoch [71/80], Train Loss: 0.3245 Train Accuracy: 91.03 %
# Epoch [72/80], Train Loss: 0.1067 Train Accuracy: 91.01 %
# Epoch [73/80], Train Loss: 0.1775 Train Accuracy: 91.07 %
# Epoch [74/80], Train Loss: 0.0995 Train Accuracy: 91.25 %
# Epoch [75/80], Train Loss: 0.5567 Train Accuracy: 91.35 %
# Epoch [76/80], Train Loss: 0.2047 Train Accuracy: 91.51 %
# Epoch [77/80], Train Loss: 0.2034 Train Accuracy: 91.32 %
# Epoch [78/80], Train Loss: 0.2607 Train Accuracy: 91.42 %
# Epoch [79/80], Train Loss: 0.1015 Train Accuracy: 91.49 %
# Epoch [80/80], Train Loss: 0.2878 Train Accuracy: 91.29 %
# time: 1h 18min 35s

# %%
import matplotlib.pyplot as plt
import numpy as np

def convert_to_imshow_format(image):
    # first convert back to [0,1] range from [-1,1] range
    image = image / 2 + 0.5
    image = image.numpy()
    # convert from CHW to HWC
    # from 3x32x32 to 32x32x3
    return image.transpose(1,2,0)

dataiter = iter(train_loader)
images, labels = dataiter.next()

fig, axes = plt.subplots(1, len(images), figsize=(12,2.5))
for idx, image in enumerate(images):
    axes[idx].imshow(convert_to_imshow_format(image))
    axes[idx].set_title(classes[labels[idx]])
    axes[idx].set_xticks([])
    axes[idx].set_yticks([])
# Out:
# time: 1 s

# %%
dataiter = iter(test_loader)
images, labels = dataiter.next()

fig, axes = plt.subplots(1, len(images), figsize=(12,2.5))
for idx, image in enumerate(images):
    axes[idx].imshow(convert_to_imshow_format(image))
    axes[idx].set_title(classes[labels[idx]])
    axes[idx].set_xticks([])
    axes[idx].set_yticks([])
# Out:
# time: 991 ms

# %%
images = images.to(device)
labels = labels.to(device)
outputs = model(images)
# Out:
# time: 11.2 ms

# %%
sm = nn.Softmax(dim=1)
sm_outputs = sm(outputs)
# Out:
# time: 1.51 ms

# %%
probs, index = torch.max(sm_outputs, dim=1)

for p, i in zip(probs, index):
    print('{0} - {1:.4f}'.format(classes[i], p))
# Out:
# cat - 0.6840
# ship - 0.9986
# ship - 0.9736
# plane - 0.5356
# frog - 0.9991
# frog - 0.9344
# car - 0.6057
# frog - 0.9573
# cat - 0.9115
# car - 0.9361
# plane - 0.9906
# truck - 0.9999
# dog - 0.8679
# horse - 0.9994
# truck - 0.9761
# ship - 0.8125
# dog - 0.9873
# horse - 0.9998
# ship - 0.9999
# frog - 0.9999
# horse - 0.9942
# plane - 0.9362
# deer - 0.6796
# truck - 0.9996
# dog - 0.4560
# cat - 0.4412
# deer - 0.9927
# plane - 0.9984
# truck - 0.9992
# frog - 0.9924
# frog - 0.7199
# dog - 0.9992
# time: 14.7 ms

# %% [markdown]
# ## Accuracy on test data

# %%
total_correct = 0
total_images = 0
confusion_matrix = np.zeros([10,10], int)
with torch.no_grad():
    for data in test_loader:
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total_images += labels.size(0)
        total_correct += (predicted == labels).sum().item()
        for i, l in enumerate(labels):
            confusion_matrix[l.item(), predicted[i].item()] += 1 

model_accuracy = total_correct / total_images * 100
print('Model accuracy on {0} test images: {1:.2f}%'.format(total_images, model_accuracy))
# Out:
# Model accuracy on 10000 test images: 87.43%
# time: 2.8 s

# %% [markdown]
# ## Accuracy per class

# %%
print('{0:10s} - {1}'.format('Category','Accuracy'))
for i, r in enumerate(confusion_matrix):
    print('{0:10s} - {1:.1f}'.format(classes[i], r[i]/np.sum(r)*100))
# Out:
# Category   - Accuracy
# plane      - 88.4
# car        - 94.0
# bird       - 82.5
# cat        - 70.5
# deer       - 88.6
# dog        - 81.8
# frog       - 90.2
# horse      - 91.0
# ship       - 94.7
# truck      - 92.6
# time: 2.11 ms

# %% [markdown]
# ## Confusion Matrix

# %%
fig, ax = plt.subplots(1,1,figsize=(10,8))
ax.matshow(confusion_matrix, aspect='auto', vmin=0, vmax=1000, cmap=plt.get_cmap('Blues'),)
for (i, j), z in np.ndenumerate(confusion_matrix):
    ax.text(j, i, '{:0.1f}'.format(z), ha='center', va='center',
            bbox=dict(boxstyle='round', facecolor='white', edgecolor='0.3'))
plt.ylabel('Actual Category')
plt.yticks(range(10), classes)
plt.xlabel('Predicted Category')
plt.xticks(range(10), classes)
plt.show()
# Out:
# time: 493 ms

# %%
# Save the model checkpoint
torch.save(model.state_dict(), 'resnet.ckpt')
# Out:
# time: 27.5 ms

# %% [markdown]
# ## Total Parameters

# %%
pytorch_total_params = sum(p.numel() for p in model.parameters())
pytorch_total_params
# Out:
# 701466
# time: 5 ms
